# %%
from google.cloud import bigquery
from google.cloud import storage
import os
import json
import pandas as pd
import requests
from datetime import datetime, timedelta

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "leadsreporting-680714dc15e1.json"

# %%
bq = bigquery.Client()

# %% [markdown]
# ### Read and format the historical data from Rory's CDK export

# %%
df = pd.read_csv("../2_data/Historical Leads 1-1-2017_4-24-2019.csv", encoding="unicode_escape")
len(df.columns), len(df)
# Out:
# (44, 338446)

# %%
sorted(df.columns)
# Out:
# ['Actual  Response Time (Minutes)',
#  'Ad Source',
#  'Address',
#  'Appointment Set',
#  'Appointment Show',
#  'Assigned CSR',
#  'Back Gross',
#  'Birth Year',
#  'City',
#  'Customer-Id',
#  'Date/Time In',
#  'Days to Sale',
#  'Deal No',
#  'Deal-Id',
#  'Front Gross',
#  'Gender',
#  'Location',
#  'Location State',
#  'Logged By User',
#  'Lost Sale Reason',
#  'OEM',
#  'Original Event Date',
#  'Prospect Type',
#  'Provider',
#  'Purchase Method',
#  'Sale Type',
#  'Sales Manager',
#  'Sales Person 2',
#  'Salesperson',
#  'Selling Price',
#  'Sold Date',
#  'Source',
#  'State',
#  'Status',
#  'Stock ',
#  'Stock Type',
#  'Sub-status',
#  'Total Gross',
#  'TradeIn-Year-Make-Model',
#  'Vehicle',
#  'Vehicle Make',
#  'Vehicle Model',
#  'Vehicle Year',
#  'Zip']

# %%
# format datetime fields for BQ
def prep_date(col, out_format="%Y-%m-%d %H:%M:%S"):
    d_clean = pd.to_datetime(col, errors='ignore')
    return d_clean.apply(lambda x: x.strftime(out_format))
df['Date/Time In'] = prep_date(df['Date/Time In'])
df['Original Event Date'] = prep_date(df['Original Event Date'])

# %%
# format date fields for BQ
def clean_date(date):
    try:
        return datetime.strptime(str(date), "%m/%d/%Y").strftime("%Y-%m-%d")
    except:
        return None
df['Sold Date'] = clean_date(df['Sold Date'])

# %%
df.drop(labels = ['Actual  Response Time (Minutes)',
                  'City', 
                  'State', 
                  'Zip', 
                  'OEM', 
                  'Location State', 
                  'Gender', 
                  'Address'], axis=1, inplace=True)

# %%
col_mapping = {'Ad Source': 'ad_source',
            'Appointment Set': 'appt_set',
            'Appointment Show': 'appt_show',
            'Assigned CSR': 'assigned_csr',
            'Back Gross': 'back_gross',
            'Customer-Id': 'client_id',
            'Birth Year': 'birth_year',
            'Date/Time In': 'date_time_in',
            'Days to Sale': 'days_to_sale',
            'Deal-Id': 'deal_id',
            'Deal No': 'deal_num',
            'Front Gross': 'front_gross',
            'Location': 'location',
            'Logged By User': 'logged_by_user',
            'Lost Sale Reason': 'lost_sale_reason',
            'Original Event Date': 'original_event_date',
            'Prospect Type': 'prospect_type',
            'Provider': 'provider',
            'Purchase Method': 'purchase_method',
            'Sale Type': 'sale_type',
            'Sales Manager': 'sales_manager',
            'Salesperson': 'sales_person',
            'Sales Person 2': 'sales_person_2',
            'Selling Price': 'selling_price',
            'Sold Date': 'sold_date',
            'Source': 'source',
            'Status': 'status',
            'Stock ': 'stock',
            'Stock Type': 'stock_type',
            'Sub-status': 'sub_status',
            'Total Gross': 'total_gross',
            'TradeIn-Year-Make-Model': 'tradein_vehicle',
            'Vehicle': 'vehicle',
            'Vehicle Make': 'vehicle_make',
            'Vehicle Model': 'vehicle_model',
            'Vehicle Year': 'vehicle_year'}

df.rename(index=str, columns = col_mapping, inplace=True)

# %%
# create fake last_action_date field for testing
df['last_action_date'] = df ['date_time_in']

# %%
df.head().T
# Out:
#                                                             0  \
# status                                              Lost Sale
# date_time_in                              2017-06-30 23:53:00
# stock                                                     NaN
# stock_type                                                New
# vehicle               2017 Mercedes-Benz Metris Passenger Van
# vehicle_year                                             2017
# vehicle_make                                    Mercedes-Benz
# vehicle_model                            Metris Passenger Van
# source                                       Inbound Internet
# sales_person                                   Bedford, Corey
# original_event_date                       2017-06-30 00:00:00
# sub_status                                    INT No Response
# lost_sale_reason                                          NaN
# deal_num                                                  NaN
# ad_source                                                 NaN
# prospect_type                                    New Customer
# sales_person_2                                            NaN
# sales_manager                                             NaN
# sale_type                                                 NaN
# logged_by_user                                 Vining, Connor
# assigned_csr                                              NaN
# tradein_vehicle                                           NaN
# sold_date                                                None
# purchase_method                                       Finance
# front_gross                                                 0
# back_gross                                                  0
# total_gross                                                 0
# birth_year                                                NaN
# appt_set                                                   No
# appt_show                                                  No
# location                       Park Place Motorcars Grapevine
# provider                        TrueCar: New Customer Inquiry
# days_to_sale                                              NaN
# deal_id                                               1727603
# client_id                                         1.81835e+06
# selling_price                                               0
# last_action_date                          2017-06-30 23:53:00
#
#                                               1                           2  \
# status                                Delivered                   Lost Sale
# date_time_in                2017-06-30 23:51:00         2017-06-30 23:44:00
# stock                                  H5175967                   LXG006708
# stock_type                                  New                        Used
# vehicle                       2017 Lexus GX460             2016 Lexus RX350
# vehicle_year                               2017                        2016
# vehicle_make                              Lexus                       Lexus
# vehicle_model                             GX460                       RX350
# source                         Inbound Internet            Inbound Internet
# sales_person                         Elam, Josh                Herring, Rob
# original_event_date         2017-06-30 00:00:00         2017-06-30 00:00:00
# sub_status                      INT No Response             INT No Response
# lost_sale_reason                            NaN                         NaN
# deal_num                                 392892                         NaN
# ad_source                     Web Ads -- Costco   Web Ads -- autotrader.com
# prospect_type                        Owner Base                New Customer
# sales_person_2                        Orr, Alex                         NaN
# sales_manager                         Oden, Lee                         NaN
# sale_type                                Retail                         NaN
# logged_by_user                   Fardeecey, Ned                Herring, Rob
# assigned_csr                                NaN                         NaN
# tradein_vehicle                2009 Lexus RX350                         NaN
# sold_date                                  None                        None
# purchase_method                         Finance                         NaN
# front_gross                             1529.25                           0
# back_gross                                  855                           0
# total_gross                             2384.25                           0
# birth_year                                 1958                         NaN
# appt_set                                     No                          No
# appt_show                                    No                          No
# location             Park Place Lexus Grapevine  Park Place Lexus Grapevine
# provider                                 Costco              AutoTrader.com
# days_to_sale                                  5                         NaN
# deal_id                                 1727578                     1727581
# client_id                                287346                 1.81833e+06
# selling_price                             55362                           0
# last_action_date            2017-06-30 23:51:00         2017-06-30 23:44:00
#
#                                                             3  \
# status                                              Lost Sale
# date_time_in                              2017-06-30 23:34:00
# stock                                                  M25607
# stock_type                                               Used
# vehicle                              2014 Jeep Wrangler SPORT
# vehicle_year                                             2014
# vehicle_make                                             Jeep
# vehicle_model                                        Wrangler
# source                                       Inbound Internet
# sales_person                                    Massey, Randy
# original_event_date                       2017-06-30 00:00:00
# sub_status                                   INT Contact Made
# lost_sale_reason                                          NaN
# deal_num                                                  NaN
# ad_source            Web Ads -- TrueCar: New Customer Inquiry
# prospect_type                                    New Customer
# sales_person_2                                            NaN
# sales_manager                                             NaN
# sale_type                                                 NaN
# logged_by_user                                  Massey, Randy
# assigned_csr                                              NaN
# tradein_vehicle                                           NaN
# sold_date                                                None
# purchase_method                                       Finance
# front_gross                                                 0
# back_gross                                                  0
# total_gross                                                 0
# birth_year                                                NaN
# appt_set                                                   No
# appt_show                                                  No
# location                          Park Place Motorcars Dallas
# provider                        TrueCar: New Customer Inquiry
# days_to_sale                                              NaN
# deal_id                                               1727586
# client_id                                         1.81834e+06
# selling_price                                               0
# last_action_date                          2017-06-30 23:34:00
#
#                                                4
# status                                 Lost Sale
# date_time_in                 2017-06-30 23:24:00
# stock                                     M25691
# stock_type                                  Used
# vehicle                      2010 Toyota Corolla
# vehicle_year                                2010
# vehicle_make                              Toyota
# vehicle_model                            Corolla
# source                          Inbound Internet
# sales_person                       Massey, Randy
# original_event_date          2017-06-30 00:00:00
# sub_status                      INT Contact Made
# lost_sale_reason                             NaN
# deal_num                                     NaN
# ad_source              Web Ads -- AutoTrader.com
# prospect_type                       New Customer
# sales_person_2                               NaN
# sales_manager                                NaN
# sale_type                                    NaN
# logged_by_user                     Massey, Randy
# assigned_csr                                 NaN
# tradein_vehicle                              NaN
# sold_date                                   None
# purchase_method                              NaN
# front_gross                                    0
# back_gross                                     0
# total_gross                                    0
# birth_year                                   NaN
# appt_set                                      No
# appt_show                                     No
# location             Park Place Motorcars Dallas
# provider                          autotrader.com
# days_to_sale                                 NaN
# deal_id                                  1727565
# client_id                            1.81832e+06
# selling_price                                  0
# last_action_date             2017-06-30 23:24:00

# %%
# save just the first 1k rows for testing
df.iloc[0:1000].to_csv("../2_data/Historical Leads 1-1-2017_4-24-2019 - CLEAN-Sample.csv", index=False)

# %% [markdown]
# ### Upload formatted test csv data to cloud storage

# %%
gcs = storage.Client()

# %%
def upload_blob(bucket_name, source_file_name, destination_blob_name):
    """Uploads a file to the bucket."""
    storage_client = storage.Client()
    bucket = storage_client.get_bucket(bucket_name)
    blob = bucket.blob(destination_blob_name)

    blob.upload_from_filename(source_file_name)

    print('File {} uploaded to {}.'.format(
        source_file_name,
        destination_blob_name))

# %%
upload_blob('leads-reporting',
            '../2_data/Historical Leads 1-1-2017_4-24-2019 - CLEAN-Sample.csv',
            'leads_historical.csv')
# Out:
# File ../2_data/Historical Leads 1-1-2017_4-24-2019 - CLEAN-Sample.csv uploaded to leads_historical.csv.

# %% [markdown]
# ### Read in schema file that was origininally output from BQ and then updated locally

# %%
with open('leads_table_schema.json', 'r') as f:
    schema = json.loads(f.read())
schema
# Out:
# [{'mode': 'NULLABLE', 'name': 'status', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'date_time_in', 'type': 'TIMESTAMP'},
#  {'mode': 'NULLABLE', 'name': 'stock', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'stock_type', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'vehicle', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'vehicle_year', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'vehicle_make', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'vehicle_model', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'source', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'sales_person', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'original_event_date', 'type': 'TIMESTAMP'},
#  {'mode': 'NULLABLE', 'name': 'sub_status', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'lost_sale_reason', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'deal_num', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'ad_source', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'prospect_type', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'sales_person_2', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'sales_manager', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'sale_type', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'logged_by_user', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'assigned_csr', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'tradein_vehicle', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'sold_date', 'type': 'DATE'},
#  {'mode': 'NULLABLE', 'name': 'purchase_method', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'front_gross', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'back_gross', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'total_gross', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'birth_year', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'appt_set', 'type': 'BOOLEAN'},
#  {'mode': 'NULLABLE', 'name': 'appt_show', 'type': 'BOOLEAN'},
#  {'mode': 'NULLABLE', 'name': 'location', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'provider', 'type': 'STRING'},
#  {'mode': 'NULLABLE', 'name': 'days_to_sale', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'deal_id', 'type': 'INTEGER'},
#  {'mode': 'NULLABLE', 'name': 'client_id', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'selling_price', 'type': 'FLOAT'},
#  {'mode': 'NULLABLE', 'name': 'last_action_date', 'type': 'TIMESTAMP'}]

# %%
# make sure schema and columns are in same order
for i in range(len(schema)):
    print(schema[i]['name'], '  -  ', df.columns[i])
# Out:
# status   -   status
# date_time_in   -   date_time_in
# stock   -   stock
# stock_type   -   stock_type
# vehicle   -   vehicle
# vehicle_year   -   vehicle_year
# vehicle_make   -   vehicle_make
# vehicle_model   -   vehicle_model
# source   -   source
# sales_person   -   sales_person
# original_event_date   -   original_event_date
# sub_status   -   sub_status
# lost_sale_reason   -   lost_sale_reason
# deal_num   -   deal_num
# ad_source   -   ad_source
# prospect_type   -   prospect_type
# sales_person_2   -   sales_person_2
# sales_manager   -   sales_manager
# sale_type   -   sale_type
# logged_by_user   -   logged_by_user
# assigned_csr   -   assigned_csr
# tradein_vehicle   -   tradein_vehicle
# sold_date   -   sold_date
# purchase_method   -   purchase_method
# front_gross   -   front_gross
# back_gross   -   back_gross
# total_gross   -   total_gross
# birth_year   -   birth_year
# appt_set   -   appt_set
# appt_show   -   appt_show
# location   -   location
# provider   -   provider
# days_to_sale   -   days_to_sale
# deal_id   -   deal_id
# client_id   -   client_id
# selling_price   -   selling_price
# last_action_date   -   last_action_date

# %% [markdown]
# ### Delete the table if it exists (clean-up during testing)

# %%
table_id = 'leadsreporting.leads_testing.leads_historical'
bq.delete_table(table_id, not_found_ok=True)
print("Deleted table '{}'.".format(table_id))
# Out:
# Deleted table 'leadsreporting.leads_testing.leads_historical'.

# %% [markdown]
# ### Create new table and load from the rest csv using the imported schema

# %%
dataset_ref = bq.dataset('leads_testing')
job_config = bigquery.LoadJobConfig()
job_config.schema = [ bigquery.SchemaField(i["name"], i["type"]) for i in schema ]
job_config.skip_leading_rows = 1
job_config.source_format = bigquery.SourceFormat.CSV
uri = "gs://leads-reporting/leads_historical.csv"

# %%
load_job = bq.load_table_from_uri(
    uri, dataset_ref.table("leads_historical"), job_config=job_config
)  # API request
print("Starting job {}".format(load_job.job_id))

load_job.result()  # Waits for table load to complete.
print("Job finished.")

destination_table = bq.get_table(dataset_ref.table("leads_historical"))
print("Loaded {} rows.".format(destination_table.num_rows))
# Out:
# Starting job 0bcd41fd-aa90-4898-b4f8-4a963921f880
# Job finished.
# Loaded 1000 rows.

# %% [markdown]
# ### Query the BQ table to get last lead/modified datetime

# %%
query_job = bq.query("""
    SELECT 
        max(date_time_in) AS max_date_time_in, 
        max(last_action_date) AS max_last_action_date
    FROM `leadsreporting`.leads_testing.leads_historical""")

results = query_job.result()
start_times = results.to_dataframe()

# %%
print('NEW       date_from  - ', start_times.iloc[0]['max_date_time_in'].strftime('%Y-%d-%dT%H:%M:%S'))
print('MODIFIED  date_from  - ', start_times.iloc[0]['max_last_action_date'].strftime('%Y-%d-%dT%H:%M:%S'))
# Out:
# NEW       date_from  -  2017-30-30T23:53:00
# MODIFIED  date_from  -  2017-30-30T23:53:00

# %% [markdown]
# ### Pull some sample rows to inspect the BQ table

# %%
sample_rows = bq.query("""
    SELECT *
    FROM `leadsreporting`.leads_testing.leads_historical
    LIMIT 10""")

results = sample_rows.result()
results.to_dataframe()
# Out:
#       status              date_time_in stock stock_type vehicle vehicle_year  \
# 0  Lost Sale 2017-06-30 22:33:00+00:00  None       Used    None         None
# 1  Lost Sale 2017-06-30 19:18:00+00:00  None       None    None         None
# 2  Lost Sale 2017-06-30 19:08:00+00:00  None       Used    None         None
# 3  Lost Sale 2017-06-30 18:40:00+00:00  None       Used    None         None
# 4  Lost Sale 2017-06-30 18:36:00+00:00  None       None    None         None
# 5  Lost Sale 2017-06-30 17:16:00+00:00  None        New    None         None
# 6  Lost Sale 2017-06-30 16:49:00+00:00  None       Used    None         None
# 7  Lost Sale 2017-06-30 16:32:00+00:00  None       Used    None         None
# 8  Lost Sale 2017-06-30 16:15:00+00:00  None       Used    None         None
# 9  Lost Sale 2017-06-30 16:13:00+00:00  None       Used    None         None
#
#   vehicle_make vehicle_model               source        sales_person  ...  \
# 0         None          None     Inbound Internet       Massey, Randy  ...
# 1         None          None     Inbound Internet   Van Sicklen, Jeff  ...
# 2         None          None  Outbound Phone Call     Mushtaq, Naseem  ...
# 3         None          None   Inbound Phone Call        Lopez, Marco  ...
# 4         None          None     Inbound Internet     Mushtaq, Naseem  ...
# 5         None          None             Showroom      Simmons, Brian  ...
# 6         None          None   Inbound Phone Call  Holyfield, Winston  ...
# 7         None          None   Inbound Phone Call    Booker, Cadarrel  ...
# 8         None          None   Inbound Phone Call    Booker, Cadarrel  ...
# 9         None          None             Showroom            Ali, Adi  ...
#
#   birth_year appt_set appt_show                        location  \
# 0        NaN    False     False     Park Place Motorcars Dallas
# 1     1980.0    False     False              Park Place Porsche
# 2        NaN    False     False          Park Place Lexus Plano
# 3     1984.0    False     False  Park Place Motorcars Arlington
# 4        NaN    False     False          Park Place Lexus Plano
# 5     1967.0    False     False        Park Place Rolls Bentley
# 6        NaN    False     False     Park Place Motorcars Dallas
# 7        NaN    False     False     Park Place Motorcars Dallas
# 8     1969.0    False     False     Park Place Motorcars Dallas
# 9     1966.0    False     False          Park Place Lexus Plano
#
#              provider days_to_sale  deal_id  client_id selling_price  \
# 0      Edmunds Direct         None  1727587  1737564.0           0.0
# 1  Cobalt - ContactUs         None  1727592  1538406.0           0.0
# 2                None         None  1727506  1064202.0           0.0
# 3                None         None  1727496   962915.0           0.0
# 4      Cobalt Website         None  1727494  1693800.0           0.0
# 5                None         None  1727473    28191.0           0.0
# 6                None         None  1727453  1818188.0           0.0
# 7                None         None  1727443  1818182.0           0.0
# 8                None         None  1727435   341516.0           0.0
# 9                None         None  1727432  1818174.0           0.0
#
#            last_action_date
# 0 2017-06-30 22:33:00+00:00
# 1 2017-06-30 19:18:00+00:00
# 2 2017-06-30 19:08:00+00:00
# 3 2017-06-30 18:40:00+00:00
# 4 2017-06-30 18:36:00+00:00
# 5 2017-06-30 17:16:00+00:00
# 6 2017-06-30 16:49:00+00:00
# 7 2017-06-30 16:32:00+00:00
# 8 2017-06-30 16:15:00+00:00
# 9 2017-06-30 16:13:00+00:00
#
# [10 rows x 37 columns]

# %% [markdown]
# ### Pull new records from API

# %%
# create some fake timestamps for testing
start_date = (datetime.today() - timedelta(days=3)).strftime('%Y-%m-%dT%H:%M:%S')
end_date = (datetime.today() - timedelta(days=2)).strftime('%Y-%m-%dT%H:%M:%S')

payload = {'date_from': start_date, 
           'date_to': end_date,
           'update': 'false'}

print(payload)

r = requests.get('https://api.parkplace.com/leads/new', params=payload)
r.status_code
# Out:
# {'date_from': '2019-04-23T08:07:55', 'date_to': '2019-04-24T08:07:55', 'update': 'false'}
# 200

# %%
leads = r.json()
api = pd.DataFrame(leads['Leads'])
print(min(api['original_event_date']), max(api['original_event_date']))
print(min(api['date_time_in']), max(api['date_time_in']))
print(min(api['last_action_date']), max(api['last_action_date']))
# Out:
# 2019-01-15 01:19:00 2019-04-24 12:29:08
# 2019-04-23 01:00:16 2019-04-24 12:29:08
# 2019-01-15 01:19:00 2019-04-24 12:29:08

# %%
len(api.columns) #API has more columns now ... need to update BQ table and schema
# Out:
# 46

# %%
sorted(api.columns)
# Out:
# ['actual_response_time',
#  'ad_source',
#  'address',
#  'appointment_set',
#  'appointment_show',
#  'assigned_csr',
#  'back_gross',
#  'birth_year',
#  'city',
#  'client_id',
#  'date_time_in',
#  'days_to_sale',
#  'deal_id',
#  'deal_num',
#  'fi_manager',
#  'front_gross',
#  'gender',
#  'has_duplicates',
#  'last_action_date',
#  'lead_id',
#  'location',
#  'logged_by_user',
#  'lost_sale_reason',
#  'original_event_date',
#  'prospect_type',
#  'provider',
#  'purchase_method',
#  'sale_type',
#  'sales_manager',
#  'sales_person',
#  'sales_person_2',
#  'selling_price',
#  'sold_date',
#  'source',
#  'state',
#  'status',
#  'stock',
#  'stock_type',
#  'sub_status',
#  'total_gross',
#  'tradein_vehicle',
#  'vehicle',
#  'vehicle_make',
#  'vehicle_model',
#  'vehicle_year',
#  'zip']

# %% [markdown]
# ### Insert new records from API into BQ table - TBD

# %% [markdown]
# ### Run BQ de-duplication query - TBD
